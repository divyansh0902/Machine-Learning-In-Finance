# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('TATAMOTORS.NS.csv')

# %%
df
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     2017-03-27  469.000000  469.149994  462.100006  464.750000  464.750000
# 1     2017-03-28  467.500000  473.000000  467.500000  472.399994  472.399994
# 2     2017-03-29  474.899994  475.000000  463.600006  469.049988  469.049988
# 3     2017-03-30  463.500000  469.799988  462.850006  468.399994  468.399994
# 4     2017-03-31  466.500000  472.500000  464.500000  465.850006  465.850006
# ...          ...         ...         ...         ...         ...         ...
# 1230  2022-03-17  432.000000  435.700012  429.549988  433.799988  433.799988
# 1231  2022-03-21  435.500000  436.299988  427.100006  427.950012  427.950012
# 1232  2022-03-22  428.100006  441.450012  421.200012  440.350006  440.350006
# 1233  2022-03-23  443.500000  447.000000  434.600006  435.799988  435.799988
# 1234  2022-03-24  430.000000  435.399994  427.549988  433.200012  433.200012
#
#         Volume
# 0      4417413
# ...

# %%
df = df[['Date',"Close"]]

df = df.rename(columns={'Date':'ds','Close':'y'})

# %%
df
# Out:
#               ds           y
# 0     2017-03-27  464.750000
# 1     2017-03-28  472.399994
# 2     2017-03-29  469.049988
# 3     2017-03-30  468.399994
# 4     2017-03-31  465.850006
# ...          ...         ...
# 1230  2022-03-17  433.799988
# 1231  2022-03-21  427.950012
# 1232  2022-03-22  440.350006
# 1233  2022-03-23  435.799988
# 1234  2022-03-24  433.200012
#
# [1235 rows x 2 columns]

# %%
#get the last 20  rows of data and store them into a new variable
last = df[len(df)-20:]
last
# Out:
#               ds           y
# 1215  2022-02-23  477.000000
# 1216  2022-02-24  427.950012
# 1217  2022-02-25  459.750000
# 1218  2022-02-28  454.049988
# 1219  2022-03-02  447.600006
# 1220  2022-03-03  437.100006
# 1221  2022-03-04  417.250000
# 1222  2022-03-07  394.000000
# 1223  2022-03-08  391.750000
# 1224  2022-03-09  405.899994
# 1225  2022-03-10  419.600006
# 1226  2022-03-11  418.149994
# 1227  2022-03-14  411.700012
# 1228  2022-03-15  413.649994
# 1229  2022-03-16  424.899994
# 1230  2022-03-17  433.799988
# 1231  2022-03-21  427.950012
# 1232  2022-03-22  440.350006
# 1233  2022-03-23  435.799988
# 1234  2022-03-24  433.200012

# %%
#get all of the rows in the data set except the last 20 rows
df = df[:-20]
df
# Out:
#               ds           y
# 0     2017-03-27  464.750000
# 1     2017-03-28  472.399994
# 2     2017-03-29  469.049988
# 3     2017-03-30  468.399994
# 4     2017-03-31  465.850006
# ...          ...         ...
# 1210  2022-02-16  498.450012
# 1211  2022-02-17  499.950012
# 1212  2022-02-18  493.149994
# 1213  2022-02-21  494.450012
# 1214  2022-02-22  478.250000
#
# [1215 rows x 2 columns]

# %%
from fbprophet import Prophet
fbp = Prophet(daily_seasonality=True)
fbp.fit(df)
future = fbp.make_future_dataframe(periods=365)
forecast = fbp.predict(future)

# %%
#Import facebooks prophet plotting libraries
from fbprophet.plot import plot_plotly
plot_plotly(fbp,forecast)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# show the models prediction for 03-25-2020
forecast[forecast.ds == '03-25-2021']['yhat']
# Out:
# 988    269.35265
# Name: yhat, dtype: float64

# %%
#Show the actual value of stock for 03-25-2020
last[last.ds == '03-25-2021']['y']
# Out:
# Series([], Name: y, dtype: float64)
